# %% [markdown]
# <a href="https://colab.research.google.com/github/hydracsnova13/pyspark_practice/blob/main/pyspark_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=81758332970ff78ffaecfb6ad54fbf8c244aa4fe2934bc654b48fc0d9527bf4b
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# ...

# %%
import pyspark

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/test_pyspark.csv")
df
# Out:
#        name  age
# 0  debanjan   21
# 1   debangi   13
# 2  debarati   46
# 3    sonjoy   51

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practice').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://65c885d4a86d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv("/content/drive/MyDrive/test_pyspark.csv")

# %%
df_pyspark.show()
# Out:
# +--------+---+
# |     _c0|_c1|
# +--------+---+
# |    name|age|
# |debanjan| 21|
# | debangi| 13|
# |debarati| 46|
# |  sonjoy| 51|
# +--------+---+

# %%
df_pyspark_col_name = spark.read.option('header','true').csv("/content/drive/MyDrive/test_pyspark.csv")
df_pyspark_col_name.show()
# Out:
# +--------+---+
# |    name|age|
# +--------+---+
# |debanjan| 21|
# | debangi| 13|
# |debarati| 46|
# |  sonjoy| 51|
# +--------+---+

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df_pyspark_col_name)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df.head(2)
# Out:
#        name  age
# 0  debanjan   21
# 1   debangi   13

# %%
df_pyspark_col_name.head(2)
# Out:
# [Row(name='debanjan', age='21'), Row(name='debangi', age='13')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 192.0+ bytes

# %%
df_pyspark_col_name.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- age: string (nullable = true)
